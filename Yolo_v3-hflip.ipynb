# %% [markdown]
# This example illustrates how to detect Concrete deterioration using YOLO.
# この例は、YOLOを使用してコンクリートの劣化等を検出する方法を示しています。
# https://github.com/experiencor/keras-yolo3

# %% [markdown]
# # Training

# %%
# (1) メモリの確保
# 必要な分だけメモリを確保するようにする。
import os

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = ""
#os.chdir('C:/Users/tokyo-risk5/Documents/Python Scripts/Keras/keras-yolo3-master')

import tensorflow as tf
from keras.backend import tensorflow_backend
import keras.backend as K
K.clear_session()                                                      # ResourceExhaustedError対策
tensorflow_backend.clear_session()                                     # ResourceExhaustedError対策

config = tf.ConfigProto(gpu_options=tf.GPUOptions(allow_growth=True))  # ResourceExhaustedErrorに対して、ｺﾒﾝﾄｱｳﾄにより解消される場合がある。
session = tf.Session(config=config)                                    # ResourceExhaustedErrorに対して、ｺﾒﾝﾄｱｳﾄにより解消される場合がある。
tensorflow_backend.set_session(session)                                # ResourceExhaustedErrorに対して、ｺﾒﾝﾄｱｳﾄにより解消される場合がある。
# Out:
# Using TensorFlow backend.

# %%
import argparse           # 使用しないので消去してよい
import numpy as np
import json
from voc import parse_voc_annotation
from yolo import create_yolov3_model, dummy_loss
from generator import BatchGenerator
from utils.utils import normalize, evaluate, makedirs
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam
from callbacks import CustomModelCheckpoint, CustomTensorBoard
from utils.multi_gpu_model import multi_gpu_model
import tensorflow as tf
import keras
from keras.models import load_model

# %%
config_min_input_size = 288
config_max_input_size = 448
#average IOU for 9 anchors: 0.69  config_noobj_scale = 5
#config_anchors = [41,274, 54,55, 84,326, 85,124, 169,338, 170,159, 273,77, 329,191, 373,358] # 1JPG-1XML

#average IOU for 9 anchors: 0.67 config_noobj_scale = 10
#config_anchors = [50,180, 53,53, 66,354, 113,103, 157,187, 157,351, 297,90, 327,199, 371,359] # 1JPG-1XML

config_anchors = [50,175, 51,52, 64,349, 112,102, 150,343, 164,177, 304,81, 324,194, 369,358]
config_labels = ['Crack', 'Efflo_c', 'Efflo_d', 'Efflo_ee', 'Efflo_er', 'Rebar_c', 'Rebar_d', 'Rebar_e']

config_train_image_folder = 'C:/Users/K.Nakamura/Desktop/Yolo_Unet/OriginalImage/'
config_train_annot_folder = 'C:/Users/K.Nakamura/Desktop/Yolo_Unet/XML150/'
config_train_cache_name =  'concrete_train.pkl'

config_train_times = 8
config_batch_size = 1
config_learning_rate = 1e-4
config_nb_epochs = 100          #defaultは1
config_ignore_thresh = 0.5
config_gpus = '0'

config_grid_scales = [1,1,1]  # deafultは [1,1,1]
#config_grid_scales = [3,2,1]  # deafultは [1,1,1]
config_obj_scale   = 10       # deafultは 10
config_noobj_scale = 10        # deafultは 1
config_xywh_scale  = 5        # deafultは 5
config_class_scale = 5        # deafultは 5

# 生成されたアンカーより最も依存しているスケールを考える場合に、それらがすべて等しい場合には、
# grid_scalesの3つの数値をすべて同じにする。スケールを大きくすると、その特定のスケールの価値が高くなり、
# 損失が大きくなり、モデルはその重みを最適化しようとする。
# 第1のスケール：入力の1/32×1/32特徴マップ上の予測
# 第2のスケール：入力の2/32×2/32特徴マップ上の予測
# 第3のスケール：入力の4/32×4/32特徴マップ上の予測

# 多くの偽陽性が出ている場合（誤検出）は、                                      obj_scale  を大きくするとよい。
# 多くの偽陰性が出ている場合（検出漏れ）は、                                    noobj_scaleを大きくするとよい。
# prediction boxのサイズと場所が適切でない場合は、                              xywh_scale を大きくするとよい。
# prediction boxが適切でも、分類スコアが低い、あるいは分類が間違っている場合は、class_scaleを大きくするとよい。

config_tensorboard_dir = 'logs'
config_saved_weights_name = 'weights_concrete.h5'
config_saved_name = 'concrete.h5'
config_debug = True

config_valid_image_folder = ''
config_valid_annot_folder = ''
config_valid_cache_name = ''

config_valid_times = 1

# %%
def create_training_instances(
    train_annot_folder,
    train_image_folder,
    train_cache,
    valid_annot_folder,
    valid_image_folder,
    valid_cache,
    labels,
):
    # parse annotations of the training set
    # トレーニングセットのアノテーションを解析する
    train_ints, train_labels = parse_voc_annotation(train_annot_folder, train_image_folder, train_cache, labels)

    # parse annotations of the validation set, if any, otherwise split the training set
    # バリデーションセットのアノテーションを解析する。もしバリデーションセットがなければトレーニングセットを分割する
    if os.path.exists(valid_annot_folder):
        valid_ints, valid_labels = parse_voc_annotation(valid_annot_folder, valid_image_folder, valid_cache, labels)
    else:
        print("valid_annot_folder not exists. Spliting the trainining set.")

        train_valid_split = int(0.8*len(train_ints))
        np.random.seed(0)
        np.random.shuffle(train_ints)
        np.random.seed()

        valid_ints = train_ints[train_valid_split:]
        train_ints = train_ints[:train_valid_split]

    # compare the seen labels with the given labels in config.json
    # 表示されたラベルをconfig.json内の指定されたラベルと比較する　　※ config.jsonは使用していない
    if len(labels) > 0:
        overlap_labels = set(labels).intersection(set(train_labels.keys()))

        print('Seen labels: \t'  + str(train_labels) + '\n')
        print('Given labels: \t' + str(labels))

        # return None, None, None if some given label is not in the dataset
        # 指定されたラベルがデータセットにない場合は「None」を返す
        if len(overlap_labels) < len(labels):
            print('Some labels have no annotations! Please revise the list of labels in the config.json.')
            return None, None, None
    else:
        print('No labels are provided. Train on all seen labels.')
        print(train_labels)
        labels = train_labels.keys()

    max_box_per_image = max([len(inst['object']) for inst in (train_ints + valid_ints)])

    return train_ints, valid_ints, sorted(labels), max_box_per_image

# %%
def create_callbacks(saved_weights_name, tensorboard_logs, model_to_save):
    makedirs(tensorboard_logs)
    
    early_stop = EarlyStopping(
        monitor     = 'loss', 
        min_delta   = 0.01, 
        patience    = 5, 
        mode        = 'min', 
        verbose     = 1
    )
    checkpoint = CustomModelCheckpoint(
        model_to_save   = model_to_save,
        filepath        = saved_weights_name,# + '{epoch:02d}.h5', 
        monitor         = 'loss', 
        verbose         = 1,
        save_best_only  = True,
        save_weights_only  = False,
        mode            = 'min', 
        period          = 1
    )
    reduce_on_plateau = ReduceLROnPlateau(
        monitor  = 'loss',
        factor   = 0.1,
        patience = 2,
        verbose  = 1,
        mode     = 'min',
        epsilon  = 0.01,
        cooldown = 0,
        min_lr   = 0
    )
    tensorboard = CustomTensorBoard(
        log_dir                = tensorboard_logs,
        write_graph            = True,
        write_images           = True,
    )    
    return [early_stop, checkpoint, reduce_on_plateau, tensorboard]

# %%
def create_model(
    nb_class, 
    anchors, 
    max_box_per_image, 
    max_grid, batch_size, 
    warmup_batches, 
    ignore_thresh, 
    multi_gpu, 
    saved_weights_name, 
    lr,
    grid_scales,
    obj_scale,
    noobj_scale,
    xywh_scale,
    class_scale  
):
    if multi_gpu > 1:
        with tf.device('/cpu:0'):
            template_model, infer_model = create_yolov3_model(
                nb_class            = nb_class, 
                anchors             = anchors, 
                max_box_per_image   = max_box_per_image, 
                max_grid            = max_grid, 
                batch_size          = batch_size//multi_gpu, 
                warmup_batches      = warmup_batches,
                ignore_thresh       = ignore_thresh,
                grid_scales         = grid_scales,
                obj_scale           = obj_scale,
                noobj_scale         = noobj_scale,
                xywh_scale          = xywh_scale,
                class_scale         = class_scale
            )
    else:
        template_model, infer_model = create_yolov3_model(
            nb_class            = nb_class, 
            anchors             = anchors, 
            max_box_per_image   = max_box_per_image, 
            max_grid            = max_grid, 
            batch_size          = batch_size, 
            warmup_batches      = warmup_batches,
            ignore_thresh       = ignore_thresh,
            grid_scales         = grid_scales,
            obj_scale           = obj_scale,
            noobj_scale         = noobj_scale,
            xywh_scale          = xywh_scale,
            class_scale         = class_scale
        )  

    # load the pretrained weight if exists, otherwise load the backend weight only
    # pretrained weightが存在するならロードし、存在しなければbackend weightのみをロードする
    if os.path.exists(saved_weights_name): 
        print("\nLoading pretrained weights.\n")
        template_model.load_weights(saved_weights_name)
    else:
        template_model.load_weights("backend.h5", by_name=True)
        #template_model.load_weights("yolo_v3-weight.h5", by_name=True)
                        
    if multi_gpu > 1:
        train_model = multi_gpu_model(template_model, gpus=multi_gpu)
    else:
        train_model = template_model      

    optimizer = Adam(lr=lr, clipnorm=0.001)
    train_model.compile(loss=dummy_loss, optimizer=optimizer)
    
    # predict.pyで、重み読み込み時に「No training configuration found in save file」が出るため,追記
    infer_model.compile(loss=dummy_loss, optimizer=optimizer)             

    return train_model, infer_model

# %%
#config_path = args.conf

#with open(config_path) as config_buffer:
    #config = json.loads(config_buffer.read())

###############################
#   Parse the annotations 　　アノテーションを解析
###############################
train_ints, valid_ints, labels, max_box_per_image = create_training_instances(
    config_train_annot_folder,
    config_train_image_folder,
    config_train_cache_name,
    config_valid_annot_folder,
    config_valid_image_folder,
    config_valid_cache_name,config_labels
)
print('\nTraining on: \t' + str(labels) + '\n')

###############################
#   Create the generators 　　ジェネレータを作成
###############################    
train_generator = BatchGenerator(
    instances           = train_ints,
    anchors             = config_anchors,
    labels              = labels,
    downsample          = 32, # ratio between network input's size and network output's size, 32 for YOLOv3
    max_box_per_image   = max_box_per_image,
    batch_size          = config_batch_size,
    min_net_size        = config_min_input_size,
    max_net_size        = config_max_input_size,
    shuffle             = True,
    jitter              = 0.3,
    norm                = normalize
)
    
valid_generator = BatchGenerator(
    instances           = valid_ints,
    anchors             = config_anchors,
    labels              = labels,
    downsample          = 32, # ratio between network input's size and network output's size, 32 for YOLOv3
    max_box_per_image   = max_box_per_image,
    batch_size          = config_batch_size,
    min_net_size        = config_min_input_size,
    max_net_size        = config_max_input_size,
    shuffle             = True,
    jitter              = 0.0,
    norm                = normalize
)

###############################
#   Create the model 　　モデルを作成
###############################
    
config_warmup_epochs = 3

if os.path.exists(config_saved_weights_name):
    config_warmup_epochs = 0
warmup_batches = config_warmup_epochs * (config_train_times*len(train_generator))   

os.environ['CUDA_VISIBLE_DEVICES'] = config_gpus
multi_gpu = len(config_gpus.split(','))

train_model, infer_model = create_model(
    nb_class            = len(labels),
    anchors             = config_anchors,
    max_box_per_image   = max_box_per_image,
    max_grid            = [config_max_input_size, config_max_input_size], 
    batch_size          = config_batch_size,
    warmup_batches      = warmup_batches,
    ignore_thresh       = config_ignore_thresh,
    multi_gpu           = multi_gpu,
    saved_weights_name  = config_saved_weights_name,
    lr                  = config_learning_rate,
    grid_scales         = config_grid_scales,
    obj_scale           = config_obj_scale,
    noobj_scale         = config_noobj_scale,
    xywh_scale          = config_xywh_scale,
    class_scale         = config_class_scale,
)

###############################
#   Kick off the training 　　学習を開始
###############################
callbacks = create_callbacks(config_saved_weights_name, config_tensorboard_dir, infer_model)

train_model.fit_generator(
    generator        = train_generator,
    steps_per_epoch  = len(train_generator) * config_train_times,
    epochs           = config_nb_epochs + config_warmup_epochs,
    verbose          = 2 if config_debug else 1,
    callbacks        = callbacks,
    workers          = 4,
    max_queue_size   = 3  # defaultは8  #7/28修正　3→8
    #max_queue_size   = 3
)

# make a GPU version of infer_model for evaluation
# 評価用のinfer_modelのGPU版を作る
if multi_gpu > 1:
    ##########
    
    print(multi_gpu)
    
    ##########
    
    infer_model = load_model(config_saved_weights_name)

###############################
#   Run the evaluation 　　評価を実行
###############################   
# compute mAP for all the classes
# 全クラスに対するmAPを計算
average_precisions = evaluate(infer_model, valid_generator)

# print the score
# スコアを表示
for label, average_precision in average_precisions.items():
    print(labels[label] + ': {:.4f}'.format(average_precision))
print('mAP: {:.4f}'.format(sum(average_precisions.values()) / len(average_precisions)))
# Out:
# valid_annot_folder not exists. Spliting the trainining set.
# Seen labels: 	{'Crack': 354, 'Efflo_c': 370, 'Efflo_d': 420, 'Efflo_ee': 401, 'Rebar_d': 404, 'Efflo_er': 404, 'Rebar_c': 318, 'Rebar_e': 300}
#
# Given labels: 	['Crack', 'Efflo_c', 'Efflo_d', 'Efflo_ee', 'Efflo_er', 'Rebar_c', 'Rebar_d', 'Rebar_e']
#
# Training on: 	['Crack', 'Efflo_c', 'Efflo_d', 'Efflo_ee', 'Efflo_er', 'Rebar_c', 'Rebar_d', 'Rebar_e']
#
#
# Loading pretrained weights.
# C:\Users\K.Nakamura\Anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\callbacks.py:1065: UserWarning: `epsilon` argument is deprecated and will be removed, use `min_delta` instead.
#   warnings.warn('`epsilon` argument is deprecated and '
# Epoch 1/100
# resizing:  384 384
# Cannot find  C:/Users/K.Nakamura/Desktop/Yolo_Unet/OriginalImage/hflip_Efee143_add.jpg
# resizing:  416 416
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-620fea71537b> in <module>
#      91     callbacks        = callbacks,
#      92     workers          = 4,
# ---> 93     max_queue_size   = 3  # defaultは8  #7/28修正　3→8
#      94     #max_queue_size   = 3
#      95 )
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     179             batch_index = 0
#     180             while steps_done < steps_per_epoch:
# --> 181                 generator_output = next(output_generator)
#     182
#     183                 if not hasattr(generator_output, '__len__'):
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\utils\data_utils.py in get(self)
#     599         except Exception as e:
#     600             self.stop()
# --> 601             six.reraise(*sys.exc_info())
#     602
#     603
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\utils\data_utils.py in get(self)
#     593         try:
#     594             while self.is_running():
# --> 595                 inputs = self.queue.get(block=True).get()
#     596                 self.queue.task_done()
#     597                 if inputs is not None:
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\multiprocessing\pool.py in get(self, timeout)
#     642             return self._value
#     643         else:
# --> 644             raise self._value
#     645
#     646     def _set(self, i, obj):
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\multiprocessing\pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     117         job, i, func, args, kwds = task
#     118         try:
# --> 119             result = (True, func(*args, **kwds))
#     120         except Exception as e:
#     121             if wrap_exception and func is not _helper_reraises_exception:
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\utils\data_utils.py in get_index(uid, i)
#     399         The value at index `i`.
#     400     """
# --> 401     return _SHARED_SEQUENCES[uid][i]
#     402
#     403
#
# ~\Desktop\Yolo_Unet\Segmentation\Concrete\Concrete\Concrete\generator.py in __getitem__(self, idx)
#      71         for train_instance in self.instances[l_bound:r_bound]:
#      72             # augment input image and fix object's position and size
# ---> 73             img, all_objs = self._aug_image(train_instance, net_h, net_w)
#      74
#      75             for obj in all_objs:
#
# ~\Desktop\Yolo_Unet\Segmentation\Concrete\Concrete\Concrete\generator.py in _aug_image(self, instance, net_h, net_w)
#     161
#     162         if image is None: print('Cannot find ', image_name)
# --> 163         image = image[:,:,::-1] # RGB image
#     164
#     165         image_h, image_w, _ = image.shape
#
# TypeError: 'NoneType' object is not subscriptable

# %%
#train_model.save_weights(config_saved_weights_name)
train_model.save(config_saved_name)

#train_model.save_weights('weights_concrete.h5')
# ↑callbacksで保存されたmodel+weightに、weightのみで上書してしまうため、コメントアウトする
#train_model.save('concrete.h5')

#if __name__ == '__main__':
    #argparser = argparse.ArgumentParser(description='train and evaluate YOLO_v3 model on any dataset')
    #argparser.add_argument('-c', '--conf', help='path to configuration file')   

    #args = argparser.parse_args()
    #_main_(args)

# %% [markdown]
# # Test

# %%
# 必要な分だけメモリを確保するようにする。
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = ""
os.chdir('C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/Segmentation/Concrete/Concrete/Concrete')

import tensorflow as tf
from keras.backend import tensorflow_backend
import keras.backend as K
K.clear_session()                                                      # ResourceExhaustedError対策
tensorflow_backend.clear_session()                                     # ResourceExhaustedError対策

config = tf.ConfigProto(gpu_options=tf.GPUOptions(allow_growth=True))  # ResourceExhaustedErrorに対して、ｺﾒﾝﾄｱｳﾄにより解消される場合がある。
session = tf.Session(config=config)                                    # ResourceExhaustedErrorに対して、ｺﾒﾝﾄｱｳﾄにより解消される場合がある。
tensorflow_backend.set_session(session)                                # ResourceExhaustedErrorに対して、ｺﾒﾝﾄｱｳﾄにより解消される場合がある。

# %%
import argparse           # 使用しないので消去してよい
import json
import cv2
from utils.utils import get_yolo_boxes, makedirs
from utils.bbox import draw_boxes
from keras.models import load_model
from tqdm import tqdm
import numpy as np

from keras.optimizers import Adam

# %%
input_path   = 'C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/'
output_path  = 'C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OutputImage_2/'
anchors = [47,339, 54,53, 67,149, 104,335, 171,84, 173,180, 226,315, 347,132, 382,345] # 1JPG-1XML

# anchors = [48,51, 55,161, 59,345, 119,90, 141,346, 157,179, 311,93, 326,205, 372,372]
labels  = ['Crack', 'Efflo_c', 'Efflo_d', 'Efflo_ee', 'Efflo_er', 'Rebar_c', 'Rebar_d', 'Rebar_e']

makedirs(output_path)

###############################
#   Set some parameter
###############################       
net_h, net_w = 416, 416 # a multiple of 32, the smaller the faster
obj_thresh, nms_thresh = 0.1, 0.1
#obj_thresh, nms_thresh = 0.50, 0.45

###############################
#   Load the model
###############################
from yolo import dummy_loss
infer_model = load_model('weights_concrete.h5',custom_objects={'dummy_loss': dummy_loss})

#infer_model = load_model('concrete.h5',custom_objects={'dummy_loss': dummy_loss})
#infer_model = load_model('weights_concrete.h5')
#infer_model = load_model('weights_concrete_test.h5')
#infer_model = load_model('concrete.h5')
#infer_model = load_model('concrete_Topt.h5')
#infer_model = load_model('concrete_Fopt.h5')
    
### ネットで他の案件のissueを見て追記した
#config_learning_rate = 1e-4
#lr = config_learning_rate
#optimizer = Adam(lr=lr, clipnorm=0.001)
#from yolo import dummy_loss
#infer_model.compile(loss=dummy_loss, optimizer=optimizer)

# %%
###############################
#   Predict bounding boxes（静止画）
###############################

# do detection on an image or a set of images
# 1つの画像または複数の画像の検出を行う
image_paths = []

if os.path.isdir(input_path): 
    for inp_file in os.listdir(input_path):
        image_paths += [input_path + inp_file]
else:
    image_paths += [input_path]

image_paths = [inp_file for inp_file in image_paths if (inp_file[-4:] in ['.jpg','.JPG', '.png', 'JPEG'])]

# the main loop
for image_path in image_paths:
    image = cv2.imread(image_path)
    print(image_path)
    
    # predict the bounding boxes
    boxes = get_yolo_boxes(infer_model, [image], net_h, net_w, anchors, obj_thresh, nms_thresh)[0]
    
    # draw bounding boxes on the image using labels
    draw_boxes(image, boxes, labels, obj_thresh) 
    
    # write the image with bounding boxes to file
    cv2.imwrite(output_path + image_path.split('/')[-1], np.uint8(image))
# Out:
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra001.JPG
# 286
# 1
# 349
# 453
# Crack 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra002.JPG
# 242
# 5
# 316
# 447
# Crack 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra003.JPG
# 155
# -5
# 363
# 458
# Crack 97.64%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra004.JPG
# 228
# 0
# 285
# 452
# Crack 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra005.JPG
# 261
# 5
# 296
# 446
# Crack 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra006.JPG
# 249
# 4
# 321
# 447
# Crack 99.99%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra007.JPG
# 284
# 0
# 328
# 445
# Crack 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra008.JPG
# 288
# 4
# 349
# 448
# Crack 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra009.JPG
# 233
# -12
# 397
# 466
# Crack 99.99%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra010.JPG
# 236
# 13
# 339
# 443
# Crack 99.41%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra011.JPG
# 275
# 6
# 360
# 446
# Crack 99.99%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra012.JPG
# 253
# 6
# 338
# 446
# Crack 99.99%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra013.JPG
# 182
# 0
# 413
# 450
# Crack 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra014.JPG
# 260
# -2
# 353
# 434
# Crack 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra015.JPG
# 282
# 4
# 368
# 450
# Crack 99.99%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra016.JPG
# -4
# 121
# 602
# 219
# Crack 100.0%
# 260
# 231
# 320
# 452
# Crack 99.99%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra017.JPG
# 272
# -2
# 366
# 379
# Crack 99.8%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra018.JPG
# 440
# 22
# 559
# 944
# Crack 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra019.JPG
# 1093
# -23
# 1334
# 1803
# Crack 99.99%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra020.JPG
# 98
# 340
# 972
# 449
# Crack 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra021.JPG
# 265
# -2
# 851
# 549
# Crack 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra022.JPG
# 275
# -2
# 372
# 667
# Crack 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra023.JPG
# 481
# -10
# 742
# 978
# Crack 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra024.JPG
# 13
# 451
# 1094
# 674
# Crack 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra025.JPG
# -4
# 311
# 371
# 523
# Crack 99.86%
# 401
# 43
# 545
# 397
# Crack 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra026.JPG
# 38
# 355
# 1224
# 459
# Crack 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra027.JPG
# 321
# 109
# 846
# 1231
# Crack 99.99%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra028.JPG
# 328
# 248
# 470
# 1286
# Crack 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra029.JPG
# 14
# 556
# 1257
# 954
# Crack 100.0%
# 395
# 18
# 1149
# 560
# Efflo_c 99.93%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra030.JPG
# 931
# 23
# 1053
# 1522
# Crack 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra031.JPG
# 653
# 168
# 766
# 968
# Crack 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra032.JPG
# 376
# 1
# 672
# 893
# Crack 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra033.JPG
# 414
# -3
# 737
# 970
# Crack 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Cra034.JPG
# 540
# -6
# 819
# 972
# Crack 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/C
# Rebar_e 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree119.JPG
# -2
# 2
# 514
# 280
# Rebar_e 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree120.JPG
# -3
# 8
# 515
# 300
# Rebar_e 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree121.JPG
# -6
# 39
# 569
# 411
# Rebar_e 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree122.JPG
# 2
# -5
# 1033
# 632
# Rebar_e 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree123.JPG
# -12
# 118
# 815
# 447
# Rebar_e 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree124.JPG
# 121
# 241
# 796
# 364
# Rebar_e 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree125.JPG
# -4
# 118
# 803
# 600
# Rebar_e 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree126.JPG
# 248
# 155
# 537
# 592
# Rebar_e 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree127.JPG
# -5
# 7
# 803
# 593
# Rebar_e 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree128.JPG
# -3
# 0
# 800
# 589
# Rebar_e 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree129.JPG
# -5
# 0
# 925
# 463
# Rebar_e 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree130.JPG
# 0
# 1
# 599
# 449
# Rebar_e 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree131.JPG
# -2
# 9
# 752
# 404
# Rebar_e 99.99%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree132.JPG
# -8
# 2
# 680
# 506
# Rebar_e 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree133.JPG
# -5
# 5
# 726
# 460
# Rebar_e 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree134.JPG
# 124
# 0
# 747
# 565
# Rebar_e 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree135.JPG
# -4
# 7
# 721
# 540
# Rebar_e 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree136.JPG
# -2
# -4
# 756
# 558
# Rebar_e 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree137.JPG
# -5
# 3
# 756
# 475
# Rebar_e 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree138.JPG
# 13
# 14
# 751
# 554
# Rebar_e 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree139.JPG
# 191
# 100
# 1195
# 836
# Rebar_e 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree140.JPG
# 40
# -7
# 497
# 348
# Rebar_e 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree141.JPG
# 11
# 14
# 1587
# 1194
# Rebar_e 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree142.JPG
# -5
# 29
# 1610
# 1136
# Rebar_e 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree143.JPG
# 3
# 1
# 1017
# 752
# Rebar_e 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree144.JPG
# 137
# 2
# 1365
# 1096
# Rebar_e 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree145.JPG
# 85
# 38
# 1547
# 1235
# Rebar_e 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree146.JPG
# 0
# 72
# 572
# 352
# Rebar_e 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree147.JPG
# 53
# -16
# 1418
# 1131
# Rebar_e 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree148.JPG
# -4
# 45
# 1600
# 887
# Rebar_e 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree149.JPG
# 5
# -4
# 1268
# 931
# Rebar_e 100.0%
# C:/Users/Hideaki Nakamura/Desktop/Yolo_Unet/OriginalImage/Ree150.JPG
# 153
# 27
# 1282
# 815
# Rebar_e 100.0%

# %%
###############################
#   Predict bounding boxes（動画）
###############################

input_path   = 'C:/Users/tokyo-risk5/Documents/Python Scripts/Keras/keras-yolo3-master/output/test/S2330001.mp4'

video_out = output_path + input_path.split('/')[-1]
video_reader = cv2.VideoCapture(input_path)

nb_frames = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
frame_h = int(video_reader.get(cv2.CAP_PROP_FRAME_HEIGHT))
frame_w = int(video_reader.get(cv2.CAP_PROP_FRAME_WIDTH))

video_writer = cv2.VideoWriter(video_out,
                       cv2.VideoWriter_fourcc(*'MPEG'), 
                       50.0, 
                       (frame_w, frame_h))

# the main loop
batch_size  = 1
images      = []
start_point = 0 #%
show_window = False
for i in tqdm(range(nb_frames)):
    _, image = video_reader.read()

    if (float(i+1)/nb_frames) > start_point/100.:
        images += [image]

        if (i%batch_size == 0) or (i == (nb_frames-1) and len(images) > 0):
            # predict the bounding boxes
            # バウンディングボックスの予測
            batch_boxes = get_yolo_boxes(infer_model, images, net_h, net_w, anchors, obj_thresh, nms_thresh)

            for i in range(len(images)):
                # draw bounding boxes on the image using labels
                # ラベルを使用して画像にバウンディングボックスを描画
                draw_boxes(images[i], batch_boxes[i], labels, obj_thresh)   

                # show the video with detection bounding boxes
                # 検出したバウンディングボックス付きでビデオを表示
                if show_window: cv2.imshow('video with bboxes', images[i])  

                # write result to the output video
                # 出力ビデオへの結果の書き込み
                video_writer.write(images[i]) 
            images = []
        if show_window and cv2.waitKey(1) == 27: break  # esc to quit

if show_window: cv2.destroyAllWindows()
video_reader.release()
video_writer.release()
